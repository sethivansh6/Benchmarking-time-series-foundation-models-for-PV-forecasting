# %% [markdown]
# # 08 — Final Comparison: TSFMs vs Baselines on LARES PV Dataset
#
# Aggregates results from all notebooks and produces report-ready figures.
#
# **Models:**
# | Category | Model | Weather features? |
# |---|---|---|
# | Baseline | LightGBM, MLP | ✓ Yes |
# | TSFM zero-shot | Chronos, TimesFM, Moirai | ✗ No |
# | TSFM fine-tuned | Chronos + LoRA | ✗ No |
# | Tabular FM | TabPFN | ✓ Yes |
#
# **Metrics:** MAE, RMSE, nRMSE — daytime primary (solar elevation > 5°), all-hours secondary
# **Cost proxy:** inference time per 24h window

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os

os.makedirs('../figure', exist_ok=True)
plt.rcParams.update({
    'font.size': 10,
    'axes.titlesize': 11,
    'axes.labelsize': 10,
    'figure.dpi': 120,
})

comp = pd.read_csv('../results/comparison.csv')
print(comp.to_string(index=False))
# Out:
#                          Model      MAE     RMSE    nRMSE  Train Time  Inference Time
#                       LightGBM 0.021175 0.034823 0.040512    0.196141        0.014383
#               LightGBM (tuned) 0.020895 0.034539 0.040182   66.418172        0.037487
#                            MLP 0.020945 0.034464 0.040095    2.954158        0.017441
#                        Chronos 0.164308 0.231903 0.269790    0.000000        1.622153
#              Chronos (all-hrs) 0.104663 0.188088 0.218817    0.000000        1.622153
#                        TimesFM 0.124079 0.178613 0.207794    0.000000        0.077968
#              TimesFM (all-hrs) 0.062519 0.126753 0.147461    0.000000        0.077968
#                         Moirai 0.222258 0.326228 0.379526    0.000000        0.017504
#               Moirai (all-hrs) 0.247542 0.430665 0.501025    0.000000        0.017504
#                         TabPFN 0.045660 0.089320 0.103913   11.576127        2.581436
# ...

# %%
day = comp[~comp['Model'].str.contains('all-hrs')].copy().reset_index(drop=True)
alh = comp[ comp['Model'].str.contains('all-hrs')].copy().reset_index(drop=True)
alh['Model'] = alh['Model'].str.replace(r' \(all-hrs\)', '', regex=True)

ORDER = day.sort_values('nRMSE')['Model'].tolist()
day = day.set_index('Model').loc[ORDER].reset_index()

alh_idx = [m for m in ORDER if m in alh['Model'].values]
alh = alh.set_index('Model').loc[alh_idx].reset_index()

BASELINE_MODELS = ['LightGBM', 'MLP']
TSFM_ZS_MODELS  = ['Chronos', 'TimesFM', 'Moirai']
TSFM_FT_MODELS  = ['Chronos (fine-tuned)']
TABFM_MODELS    = ['TabPFN']

PALETTE = {
    'Baseline'        : '#2196F3',
    'TSFM (zero-shot)': '#FF6B35',
    'TSFM (fine-tuned)': '#4CAF50',
    'Tabular FM'      : '#9C27B0',
}

def model_cat(name):
    if name in BASELINE_MODELS: return 'Baseline'
    if name in TSFM_FT_MODELS:  return 'TSFM (fine-tuned)'
    if name in TABFM_MODELS:    return 'Tabular FM'
    return 'TSFM (zero-shot)'

def model_color(name):
    return PALETTE[model_cat(name)]

colors = [model_color(m) for m in day['Model']]

legend_patches = [mpatches.Patch(color=v, label=k) for k, v in PALETTE.items()
                  if any(model_cat(m) == k for m in day['Model'])]

print('Model order (best→worst nRMSE):', ORDER)
# Out:
# Model order (best→worst nRMSE): ['MLP', 'LightGBM (tuned)', 'LightGBM', 'TabPFN', 'TimesFM', 'Chronos (fine-tuned)', 'Chronos', 'Moirai']

# %% [markdown]
# ## Figure 1 — nRMSE Comparison (Headline Figure)

# %%
fig, ax = plt.subplots(figsize=(11, 5))

bars = ax.bar(day['Model'], day['nRMSE'],
              color=colors, edgecolor='black', linewidth=0.7, width=0.6)

for bar, v in zip(bars, day['nRMSE']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.004,
            f'{v:.3f}', ha='center', va='bottom', fontsize=9, fontweight='bold')

ax.set_ylabel('nRMSE  (daytime, solar elevation > 5°)', fontsize=11)
ax.set_title('PV Power Forecasting — Model Comparison by nRMSE\n'
             '24h-ahead, 15-min resolution, LARES dataset (2020-01 → 2020-08)',
             fontsize=11)
ax.set_xticklabels(day['Model'], rotation=20, ha='right', fontsize=10)
ax.legend(handles=legend_patches, fontsize=9, loc='upper left')
ax.set_ylim(0, day['nRMSE'].max() * 1.20)
ax.grid(axis='y', alpha=0.35)
ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.savefig('../figure/08_nrmse_comparison.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved → ../figure/08_nrmse_comparison.png')
# Out:
# /var/folders/rq/mgccyfw13v9cd4m3bsyqdjh40000gn/T/ipykernel_37260/1051464683.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(day['Model'], rotation=20, ha='right', fontsize=10)
# Saved → ../figure/08_nrmse_comparison.png

# %% [markdown]
# ## Figure 2 — All Three Metrics Side-by-Side

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

for ax, metric in zip(axes, ['MAE', 'RMSE', 'nRMSE']):
    bars = ax.bar(day['Model'], day[metric],
                  color=colors, edgecolor='black', linewidth=0.7, width=0.6)
    for bar, v in zip(bars, day[metric]):
        ax.text(bar.get_x() + bar.get_width()/2,
                bar.get_height() + day[metric].max() * 0.012,
                f'{v:.3f}', ha='center', va='bottom', fontsize=8)
    ax.set_title(metric, fontsize=12, fontweight='bold')
    ax.set_ylabel(metric)
    ax.set_xticklabels(day['Model'], rotation=25, ha='right', fontsize=9)
    ax.set_ylim(0, day[metric].max() * 1.20)
    ax.grid(axis='y', alpha=0.35)
    ax.spines[['top', 'right']].set_visible(False)

axes[0].legend(handles=legend_patches, fontsize=8)
fig.suptitle('All Accuracy Metrics — Daytime (solar elevation > 5°)', fontsize=12)
plt.tight_layout()
plt.savefig('../figure/08_all_metrics.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved → ../figure/08_all_metrics.png')
# Out:
# /var/folders/rq/mgccyfw13v9cd4m3bsyqdjh40000gn/T/ipykernel_37260/3576251680.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(day['Model'], rotation=25, ha='right', fontsize=9)
# /var/folders/rq/mgccyfw13v9cd4m3bsyqdjh40000gn/T/ipykernel_37260/3576251680.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(day['Model'], rotation=25, ha='right', fontsize=9)
# /var/folders/rq/mgccyfw13v9cd4m3bsyqdjh40000gn/T/ipykernel_37260/3576251680.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(day['Model'], rotation=25, ha='right', fontsize=9)
# Saved → ../figure/08_all_metrics.png

# %% [markdown]
# ## Figure 3 — Cost vs Accuracy (Inference Time vs nRMSE)

# %%
NUDGE = {
    'LightGBM'            : ( 0,  0.012),
    'MLP'                 : ( 0, -0.018),
    'Chronos'             : ( 0,  0.010),
    'TimesFM'             : ( 0,  0.010),
    'Moirai'              : ( 0,  0.010),
    'Chronos (fine-tuned)': ( 0, -0.018),
    'TabPFN'              : ( 0,  0.010),
}

fig, ax = plt.subplots(figsize=(10, 6))

for _, row in day.iterrows():
    c = model_color(row['Model'])
    ax.scatter(row['Inference Time'], row['nRMSE'],
               color=c, s=140, edgecolors='black', linewidth=0.8, zorder=5)
    dx, dy = NUDGE.get(row['Model'], (0, 0.010))
    ax.annotate(row['Model'],
                xy=(row['Inference Time'], row['nRMSE']),
                xytext=(row['Inference Time'] * (1 + dx), row['nRMSE'] + dy),
                fontsize=9, ha='center')

ax.set_xscale('log')
ax.set_xlabel('Inference time per 24h forecast window [s]  (log scale)', fontsize=11)
ax.set_ylabel('nRMSE (daytime)', fontsize=11)
ax.set_title('Cost vs Accuracy Trade-off  ←  Ideal: bottom-left', fontsize=11)
ax.legend(handles=legend_patches, fontsize=9)
ax.grid(True, alpha=0.3)
ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.savefig('../figure/08_cost_vs_accuracy.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved → ../figure/08_cost_vs_accuracy.png')
# Out:
# Saved → ../figure/08_cost_vs_accuracy.png

# %% [markdown]
# ## Figure 4 — Daytime vs All-Hours nRMSE

# %%
shared = [m for m in ORDER if m in alh['Model'].values]
day_sh = day.set_index('Model').loc[shared]
alh_sh = alh.set_index('Model').loc[shared]
col_sh = [model_color(m) for m in shared]

x = np.arange(len(shared))
w = 0.35

fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(x - w/2, day_sh['nRMSE'], w,
       color=col_sh, edgecolor='black', linewidth=0.7, label='Daytime (solar elev > 5°)')
ax.bar(x + w/2, alh_sh['nRMSE'], w,
       color=col_sh, edgecolor='black', linewidth=0.7, alpha=0.4, label='All hours')

ax.set_xticks(x)
ax.set_xticklabels(shared, rotation=20, ha='right', fontsize=10)
ax.set_ylabel('nRMSE')
ax.set_title('nRMSE — Daytime vs All-Hours\n'
             '(all-hours lower: nighttime power = 0 is trivially easy to predict)', fontsize=11)
ax.grid(axis='y', alpha=0.35)
ax.spines[['top', 'right']].set_visible(False)

scope = [
    mpatches.Patch(facecolor='grey',           label='Daytime (solid)'),
    mpatches.Patch(facecolor='grey', alpha=0.4, label='All-hours (faded)'),
]
ax.legend(handles=legend_patches + scope, fontsize=8, ncol=2)

plt.tight_layout()
plt.savefig('../figure/08_daytime_vs_allhours.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved → ../figure/08_daytime_vs_allhours.png')
# Out:
# Saved → ../figure/08_daytime_vs_allhours.png

# %% [markdown]
# ## Figure 5 — Chronos: Zero-Shot vs Fine-Tuned (LoRA)

# %%
zs = day[day['Model'] == 'Chronos'].iloc[0]
ft = day[day['Model'] == 'Chronos (fine-tuned)'].iloc[0]
metrics = ['MAE', 'RMSE', 'nRMSE']
zs_vals  = [zs[m] for m in metrics]
ft_vals  = [ft[m] for m in metrics]
pct_imp  = [(z - f) / z * 100 for z, f in zip(zs_vals, ft_vals)]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Left — absolute values
xx, w = np.arange(len(metrics)), 0.3
axes[0].bar(xx - w/2, zs_vals, w, label='Zero-shot',
            color='#FF6B35', edgecolor='black')
axes[0].bar(xx + w/2, ft_vals, w, label='Fine-tuned (LoRA)',
            color='#4CAF50', edgecolor='black')
axes[0].set_xticks(xx); axes[0].set_xticklabels(metrics, fontsize=11)
axes[0].set_title('Chronos: Zero-Shot vs Fine-Tuned (daytime)', fontsize=11)
axes[0].legend(fontsize=9); axes[0].grid(axis='y', alpha=0.35)
axes[0].spines[['top', 'right']].set_visible(False)
for i, (z, f) in enumerate(zip(zs_vals, ft_vals)):
    axes[0].text(i - w/2, z * 1.01, f'{z:.3f}', ha='center', va='bottom', fontsize=8)
    axes[0].text(i + w/2, f * 1.01, f'{f:.3f}', ha='center', va='bottom', fontsize=8)

# Right — % improvement
bar_c = ['#4CAF50' if p > 0 else '#f44336' for p in pct_imp]
axes[1].bar(metrics, pct_imp, color=bar_c, edgecolor='black', width=0.4)
axes[1].axhline(0, color='black', linewidth=0.8)
axes[1].set_title('Error Reduction: Fine-Tuned over Zero-Shot', fontsize=11)
axes[1].set_ylabel('Reduction (%)')
axes[1].grid(axis='y', alpha=0.35)
axes[1].spines[['top', 'right']].set_visible(False)
for i, p in enumerate(pct_imp):
    axes[1].text(i, p + 0.4, f'{p:.1f}%', ha='center', va='bottom',
                 fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig('../figure/08_chronos_zs_vs_ft.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved → ../figure/08_chronos_zs_vs_ft.png')
print(f'\nnRMSE: {zs["nRMSE"]:.4f} → {ft["nRMSE"]:.4f}  ({pct_imp[2]:.1f}% improvement)')
# Out:
# Saved → ../figure/08_chronos_zs_vs_ft.png
#
# nRMSE: 0.2698 → 0.2602  (3.6% improvement)

# %% [markdown]
# ## Figure 6 — Sample Forecast Overlays (One Sunny Day, All Models)

# %%
PKL = {
    'LightGBM'            : ('../results/lightgbm_predictions.pkl',          'lightgbm'),
    'MLP'                 : ('../results/mlp_predictions.pkl',               'mlp'),
    'Chronos'             : ('../results/chronos_predictions.pkl',           'chronos'),
    'TimesFM'             : ('../results/timesfm_predictions.pkl',           'timesfm'),
    'Moirai'              : ('../results/moirai_predictions.pkl',            'moirai'),
    'Chronos (fine-tuned)': ('../results/chronos_finetuned_predictions.pkl', 'chronos_finetuned'),
    'TabPFN'              : ('../results/tabpfn_predictions.pkl',            'tabpfn'),
}

loaded = {}
for name, (path, col) in PKL.items():
    if os.path.exists(path):
        df = pd.read_pickle(path)
        if col in df.columns:
            loaded[name] = df
            print(f'✓ {name}')
        else:
            print(f'  {name}: column "{col}" not found in {list(df.columns)}')
    else:
        print(f'  {name}: file not found')

print(f'\nLoaded {len(loaded)} model(s)')
# Out:
# ✓ LightGBM
# ✓ MLP
# ✓ Chronos
# ✓ TimesFM
# ✓ Moirai
# ✓ Chronos (fine-tuned)
# ✓ TabPFN
#
# Loaded 7 model(s)

# %%
if loaded:
    # ── Build timestamp lookup from original dataset ──────────────────────────
    # Some pkl files (moirai, chronos_finetuned, tabpfn) have a 'timestamp' column.
    # Others (lightgbm, mlp, chronos, timesfm) keep the original DataFrame integer
    # index — we recover their timestamps from clean_df.
    import pickle, pathlib
    CLEAN_DF_CANDIDATES = [
        '../data/clean_df.pkl',
        '../results/clean_df.pkl',
        str(pathlib.Path('.'). resolve() / 'clean_df.pkl'),
    ]
    clean_ref = None
    for _p in CLEAN_DF_CANDIDATES:
        if os.path.exists(_p):
            clean_ref = pd.read_pickle(_p)[['timestamp', 'solar_elevation']]
            clean_ref['timestamp'] = pd.to_datetime(clean_ref['timestamp'])
            print(f'Loaded clean_df from {_p} ({len(clean_ref)} rows)')
            break
    if clean_ref is None:
        print('clean_df not found — models without timestamp column will be skipped')

    def attach_timestamps(df, name):
        '''Return df with timestamp + daytime columns, or None if impossible.'''
        df = df.copy()
        if 'timestamp' in df.columns:
            df['timestamp'] = pd.to_datetime(df['timestamp'])
            if 'daytime' not in df.columns:
                df['daytime'] = df.get('solar_elev', pd.Series(dtype=float)) > 5
            return df
        if clean_ref is not None:
            matched = clean_ref.loc[clean_ref.index.intersection(df.index)]
            df = df.join(matched)
            df['daytime'] = df['solar_elevation'] > 5
            return df
        return None

    # ── Find best sunny day using first model that has timestamps ─────────────
    best_date = None
    for _name, _df in loaded.items():
        _dft = attach_timestamps(_df, _name)
        if _dft is not None and 'timestamp' in _dft.columns:
            _dft['_date'] = _dft['timestamp'].dt.date
            _peaks = _dft[_dft['daytime']].groupby('_date')['actual'].max()
            if len(_peaks) > 3:
                best_date = _peaks.nlargest(10).index[3]
                print(f'Best sunny date: {best_date}  (from {_name})')
                break

    if best_date is None:
        print('Could not determine best date')
    else:
        n     = len(loaded)
        ncols = min(3, n)
        nrows = (n + ncols - 1) // ncols
        fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 4 * nrows), sharey=True)
        axes = np.array(axes).ravel()

        for idx, (name, df) in enumerate(loaded.items()):
            col = PKL[name][1]
            dft = attach_timestamps(df, name)
            if dft is None:
                axes[idx].set_title(f'{name}\n(no timestamps)', fontsize=9)
                axes[idx].axis('off')
                continue
            dft['_date'] = dft['timestamp'].dt.date
            sub = dft[(dft['_date'] == best_date) & dft['daytime']]
            if len(sub) == 0:
                axes[idx].set_visible(False)
                continue
            act  = sub['actual'].values.astype(float)
            pred = sub[col].values.astype(float)
            # Normalise to [0,1] so kWh-scale and unit-scale models plot together
            a_max = act.max() if act.max() > 0 else 1.0
            p_max = pred.max() if pred.max() > 0 else 1.0
            scale = max(a_max, p_max)
            act  = act  / scale
            pred = pred / scale
            t = range(len(sub))
            axes[idx].plot(t, act,  color='black', linewidth=2, label='Actual')
            axes[idx].plot(t, pred, color=model_color(name),
                           linewidth=2, linestyle='--', label=name)
            nrmse_v = day.set_index('Model')['nRMSE'].get(name, float('nan'))
            axes[idx].set_title(f'{name}  (nRMSE={nrmse_v:.3f})', fontsize=10)
            axes[idx].set_xlabel('Step (15-min)')
            axes[idx].set_ylabel('Power [normalised]')
            axes[idx].legend(fontsize=8)
            axes[idx].grid(True, alpha=0.3)
            axes[idx].spines[['top', 'right']].set_visible(False)

        for ax in axes[len(loaded):]:
            ax.set_visible(False)

        fig.suptitle(f'Sample Daytime Forecasts — {best_date} (clear sunny day)', fontsize=13)
        plt.tight_layout()
        plt.savefig('../figure/08_sample_forecasts.png', dpi=150, bbox_inches='tight')
        plt.show()
        print('Saved → ../figure/08_sample_forecasts.png')
else:
    print('No pkl files found. Run individual model notebooks first.')
# Out:
# clean_df not found — models without timestamp column will be skipped
# Best sunny date: 2020-03-15  (from Chronos)
# Saved → ../figure/08_sample_forecasts.png

# %% [markdown]
# ## Figure 7 — Summary Table (Report-Ready)

# %%
tbl = day[['Model', 'MAE', 'RMSE', 'nRMSE', 'Train Time', 'Inference Time']].copy()
tbl['Category']       = tbl['Model'].map(model_cat)
tbl['Train Time (s)'] = tbl['Train Time'].map(lambda x: f'{x:.0f}' if x > 0 else '—')
tbl['Infer. (s/24h)'] = tbl['Inference Time'].map(lambda x: f'{x:.3f}')
tbl['MAE']            = tbl['MAE'].map(lambda x: f'{x:.4f}')
tbl['RMSE']           = tbl['RMSE'].map(lambda x: f'{x:.4f}')
tbl['nRMSE']          = tbl['nRMSE'].map(lambda x: f'{x:.4f}')
tbl = tbl[['Category', 'Model', 'MAE', 'RMSE', 'nRMSE', 'Train Time (s)', 'Infer. (s/24h)']]

print('=== Table 1: Results (daytime, solar elevation > 5°) ===')
print(tbl.to_string(index=False))

# Render as figure
fig, ax = plt.subplots(figsize=(13, len(tbl) * 0.55 + 1.5))
ax.axis('off')
t = ax.table(cellText=tbl.values, colLabels=tbl.columns,
             loc='center', cellLoc='center')
t.auto_set_font_size(False)
t.set_fontsize(10)
t.scale(1, 1.7)

CAT_COLORS = {
    'Baseline'          : '#E3F2FD',
    'TSFM (zero-shot)'  : '#FFF3E0',
    'TSFM (fine-tuned)' : '#E8F5E9',
    'Tabular FM'        : '#F3E5F5',
}

for j in range(len(tbl.columns)):
    t[0, j].set_facecolor('#263238')
    t[0, j].set_text_props(color='white', fontweight='bold')

for i, row in enumerate(tbl.itertuples()):
    fc = CAT_COLORS.get(row.Category, 'white')
    for j in range(len(tbl.columns)):
        t[i + 1, j].set_facecolor(fc)

ax.set_title('Table 1 — Forecasting Accuracy (daytime, solar elevation > 5°)',
             fontsize=11, fontweight='bold', pad=20)
plt.tight_layout()
plt.savefig('../figure/08_summary_table.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved → ../figure/08_summary_table.png')
# Out:
# === Table 1: Results (daytime, solar elevation > 5°) ===
#          Category                Model    MAE   RMSE  nRMSE Train Time (s) Infer. (s/24h)
#          Baseline                  MLP 0.0209 0.0345 0.0401              3          0.017
#  TSFM (zero-shot)     LightGBM (tuned) 0.0209 0.0345 0.0402             66          0.037
#          Baseline             LightGBM 0.0212 0.0348 0.0405              0          0.014
#        Tabular FM               TabPFN 0.0457 0.0893 0.1039             12          2.581
#  TSFM (zero-shot)              TimesFM 0.1241 0.1786 0.2078              —          0.078
# TSFM (fine-tuned) Chronos (fine-tuned) 0.1629 0.2237 0.2602            231          1.701
#  TSFM (zero-shot)              Chronos 0.1643 0.2319 0.2698              —          1.622
#  TSFM (zero-shot)               Moirai 0.2223 0.3262 0.3795              —          0.018
# Saved → ../figure/08_summary_table.png

# %% [markdown]
# ## Key Findings (Print for Report)

# %%
best_bl   = day[day['Model'].isin(BASELINE_MODELS)].sort_values('nRMSE').iloc[0]
best_zs   = day[day['Model'].isin(TSFM_ZS_MODELS)].sort_values('nRMSE').iloc[0]
chron_zs  = day[day['Model'] == 'Chronos'].iloc[0]
chron_ft  = day[day['Model'] == 'Chronos (fine-tuned)'].iloc[0]
gap       = best_zs['nRMSE'] / best_bl['nRMSE']
ft_imp    = (chron_zs['nRMSE'] - chron_ft['nRMSE']) / chron_zs['nRMSE'] * 100
speed_gap = day[day['Model'] == 'Moirai']['Inference Time'].values[0] / \
            day[day['Model'] == 'MLP']['Inference Time'].values[0]

print('=' * 62)
print('  KEY FINDINGS')
print('=' * 62)
print(f'\n 1. Best baseline   : {best_bl["Model"]}  nRMSE = {best_bl["nRMSE"]:.4f}')
print(f' 2. Best zero-shot  : {best_zs["Model"]} nRMSE = {best_zs["nRMSE"]:.4f}')
print(f' 3. Best fine-tuned : Chronos (LoRA)  nRMSE = {chron_ft["nRMSE"]:.4f}')
print(f'\n 4. TSFM zero-shot gap vs baseline : {gap:.1f}× worse nRMSE')
print(f' 5. LoRA fine-tuning improves Chronos by {ft_imp:.1f}%')
print(f'    ({chron_zs["nRMSE"]:.4f} → {chron_ft["nRMSE"]:.4f})')
print(f'    Fine-tuned Chronos ≈ zero-shot TimesFM (best zero-shot TSFM)')
print(f'\n 6. Moirai is {speed_gap:.0f}× slower than MLP with {day[day["Model"]=="Moirai"]["nRMSE"].values[0]/best_bl["nRMSE"]:.0f}× higher error')
print(f'\n ROOT CAUSE:')
print(f'   TSFMs receive only raw power history.')
print(f'   Baselines use 10 meteorological/temporal features.')
print(f'   PV output is physically driven by irradiance → weather')
print(f'   information is essential; past power alone is insufficient.')
print(f'   Fine-tuning adapts the model but cannot inject missing')
print(f'   weather information.')
print('=' * 62)
# Out:
# ...
#   KEY FINDINGS
# ...
#
#  1. Best baseline   : MLP  nRMSE = 0.0401
#  2. Best zero-shot  : TimesFM nRMSE = 0.2078
#  3. Best fine-tuned : Chronos (LoRA)  nRMSE = 0.2602
#
#  4. TSFM zero-shot gap vs baseline : 5.2× worse nRMSE
#  5. LoRA fine-tuning improves Chronos by 3.6%
#     (0.2698 → 0.2602)
#     Fine-tuned Chronos ≈ zero-shot TimesFM (best zero-shot TSFM)
#
#  6. Moirai is 1× slower than MLP with 9× higher error
#
#  ROOT CAUSE:
#    TSFMs receive only raw power history.
#    Baselines use 10 meteorological/temporal features.
#    PV output is physically driven by irradiance → weather
#    information is essential; past power alone is insufficient.
#    Fine-tuning adapts the model but cannot inject missing
#    weather information.
# ...
